# %% [markdown]
# # DART 기업공시 기반 임베딩 유사도 비교

# %%
import GraphDB.utils as utils

# 삼전 vs 하이닉스 vs 엘전

samsung = """
당사는 제품의 특성에 따라 DX(Device eXperience), DS(Device Solutions)
2개의 부문과 패널 사업을 영위하는 SDC(삼성디스플레이㈜ 및 그 종속기업),
전장부품사업 등을 영위하는 Harman(Harman International Industries, Inc.
및 그 종속기업)으로 나누어 경영을 하고 있습니다.

당사는 본사를 거점으로 한국과 DX 부문 산하 해외 9개 지역총괄, DS 부문 산하 해외 5개 지역총괄의 생산ㆍ판매법인 및 SDC, Harman 산하 종속기업 등 226개의 종속기업으로 구성된 글로벌 전자 기업입니다.

각 부문별 주요 제품은 다음과 같습니다.
DX 부문	TV, 모니터, 냉장고, 세탁기, 에어컨,
스마트폰, 네트워크시스템, 컴퓨터 등
DS 부문	DRAM, NAND Flash, 모바일AP 등 
SDC	스마트폰용 OLED 패널 등
Harman	디지털 콕핏(Digital Cockpit), 카오디오, 포터블 스피커 등

[DX 부문] 
DX 부문은 TV, 모니터, 냉장고, 세탁기, 에어컨 및 스마트폰, 태블릿, 웨어러블(Wearable) 제품, 네트워크 시스템 등을 생산ㆍ판매하는 사업으로 구성되어 있습니다. 

TV사업은 2006년 부터 2023년까지 18년 연속 판매 1위를 유지하고 있습니다. 업체간 경쟁이 심화되는 가운데, 당사는 초대형 TV를 선두로 하여, 주력제품에 AI신기술을 대폭 적용해 경쟁사들과의 기술격차를 벌리고 있습니다. 또한, 가전사업은 소비자들의 다양한 요구에 맞춘 비스포크(BESPOKE)를 통해 차별화된 제품, 기술 및 디자인으로 글로벌 시장을 이끌고 있습니다.

모바일사업은 2011년부터 2023년까지 13년 연속 글로벌 출하량 1위를 유지하고 있습니다. '갤럭시(Galaxy)' 브랜드를 통해 프리미엄부터 보급형까지 다양하고 경쟁력 있는 스마트폰 라인업과 태블릿, 웨어러블, 디지털 월렛 등을 활용하여 시장 상황에 최적화된 제품 포트폴리오를 운영하고 있습니다.

당사는 업계 최고 수준의 R&D 역량을 바탕으로 지속적인 기술 혁신 및 철저한 미래 준비를 통해 고객에게 새로운 가치를 끊임없이 제공하겠습니다. 제품과 서비스의 지속적인 발전을 통해 친환경 기술 혁신을 이어가고, 연구개발을 통해 시장 패러다임 변화를 선도해 나가겠습니다. 


[DS 부문]

DS 부문은 DRAM, NAND Flash 등 제품을 생산ㆍ판매하는 메모리 반도체 사업과 모바일AP, 카메라 센서칩 등을 설계ㆍ판매하는 System LSI 사업, 반도체 제조 위탁 생산을 하는 Foundry 사업 등으로 구성되어 있습니다.

메모리 반도체 사업은 DRAM, NAND Flash 제품 등에 선단 공정 기술을 적용하고,
고부가 솔루션 중심의 사업 포트폴리오 운영을 통해 제품을 차별화하고 원가 경쟁력을 제고하는 등 질적 성장에 주력하여 전 세계 메모리 시장에서 선두 자리를 지속적으로 유지하고 있습니다.

System LSI 사업은 모바일용 반도체 사업에서 차량용 반도체 사업으로 확장을 추진 중이며, On-Device AI 적용, 고성능 IP 탑재 등 제품의 차별화를 통해 고객과 협력 강화 및 응용처를 다변화하여 시장 지배력을 확대하는 한편, 차세대 기술 개발도 지속 추진하고 있습니다.

Foundry 사업은 글로벌 시장 수요 회복 지연에 따른 부진 장기화 극복을 위해 Advanced 공정에서 지속적인 기술 경쟁력 강화를 통해 중장기 수요 확보에 집중하고 있으며, Mature 공정에서는 고객 중심의 디자인 인프라를 제공하고, 고수익 응용처 확대에 집중하고 있습니다.


[SDC]

SDC의 중소형 패널 사업은 차별화된 기술을 바탕으로 OLED 패널의 점유율을 확대하는 한편 폴더블ㆍIT(태블릿/노트북)ㆍAuto 등 다양한 응용처의 제품 출시를 통해 시장 영역을 넓혀 나가고 있습니다. 또한, 대형 패널 사업은 고화질, 초대형, 퀀텀닷(Quantum Dot) 등 프리미엄 제품 중심으로 사업을 특화하고, 기술 및 생산성 향상을 지속 추진하여 사업 경쟁력을 제고하고 있습니다.


[Harman]

Harman은 커넥티드카 제품 및 솔루션 등을 개발 및 공급하는 전장부품 사업과 일반 오디오 제품 및 프로페셔널 오디오 솔루션을 제공하는 라이프스타일 오디오 사업을 운영하고 있습니다.

전장부품 시장의 선두업체로서 완성차 업체들에게 경쟁력 있는 제품을 공급하고 있을 뿐 아니라, 오디오 시장에서도 혁신 제품 판매를 통해 일반 소비자들과 음악 애호가들 사이에서 명성을 쌓아왔습니다. 

또한, 당사 타 제품군과의 협업 확대를 통해 차별화된 고객 경험을 제공하고 자체 개발 및 전략적 인수 등을 통해 각 사업 분야에서 경쟁력을 강화하고 있습니다.
"""

sk = """
현재 당사의 주력 생산 제품은 DRAM, NAND Flash 및 MCP(Multi-chip Package)와 같은 Memory 반도체 제품입니다. 또한, 시스템 LSI 분야인 CIS(CMOS Image Sensor) 사업 및 Foundry 사업을 추진하여 종합반도체 회사로 그 영역을 넓혀가고 있습니다.

당사 정관에 근거하여 회사가 영위하는 목적사업은 다음과 같습니다.


-. 반도체소자 제조 및 판매

-. 반도체소자 기타 이와 유사한 부품을 사용하여 전자운동의 특성을 응용하는 기계, 기구 및 이에 사용되는 부품과 재료 등의 제작, 조립 및 판매

-. 컴퓨터 활용을 위한 소프트웨어 개발 및 임대업

-. 전자 전기, 통신기계, 기구 및 그 부품의 제작, 판매, 임대 및 관련 서비스업

-. 기계부분품 제조업 및 금형제조업

-. 기술연구 및 용역수탁업

-. 전자 전기기계, 기구의 임대업

-. 특수통신(위성통신 등) 방송관련 기기 제작, 판매, 임대업 및 서비스업

-. 정보서비스업

-. 출판업

-. 무역업

-. 부동산 매매 및 임대업

-. 발전업

-. 건설업

-. 전자관 제조업

-. 창고업

-. 주차장업

-. 위성통신사업

-. 전기통신회선설비 임대사업

-. 전자상거래 및 인터넷 관련사업
-. 전기 각호와 관련되는 사업 및 투자

-. 평생교육 및 평생교육시설 운영업

사업부문별 보다 자세한 사항은 Ⅱ. 사업의 내용을 참조하시기 바랍니다.
"""

lg = """
회사와 그 종속기업(이하'연결회사')의 주요 사업부문은 냉장고ㆍ세탁기ㆍ에어컨 등을 생산ㆍ판매하며, 제23기 반기 기준 전체 매출액 대비 40.8%의 비중을 차지하는 Home Appliance & Air Solution 사업본부 (H&A), TV와 디지털 미디어 제품 등을 생산ㆍ판매하며, 매출 비중은 16.6%인 Home Entertainment 사업본부 (HE), 자동차 부품 등을 설계ㆍ제조하며, 매출 비중은 12.5%인 Vehicle component Solutions 사업본부 (VS), 모니터, PC, 인포메이션 디스플레이 등을 생산ㆍ판매하며, 매출 비중은 7.1%인 Business Solutions 사업본부 (BS) 그리고 광학솔루션사업 등을 영위하며 매출 비중은 20.8%인 엘지이노텍의 5개로 구성되어 있습니다. 연결회사의 주요 매출처는 Best Buy, HOME DEPOT, LOWE'S 등이 있으며, 기타 자세한 사항은 「Ⅱ. 사업의 내용」을 참조 바랍니다.
"""
# utils.text_embed()

# %%
utils.calculate_cosine_similarity(samsung, sk)
# Out:
# ## client loaded ##
# ## config file loaded ##
# ## 서버와의 연결이 성공적으로 확인되었습니다.
# ## config file loaded ##
# 0.5276761806467345

# %%
utils.calculate_cosine_similarity(samsung, lg)
# Out:
# 0.5740182132926307

# %%
utils.calculate_cosine_similarity(lg, sk)
# Out:
# 0.4899164367235139

# %%
prompt = "너는 기업공시 전문가야. 산업군별로 묶어서 연관 주식 종목을 찾는 작업을 수행하려 해. 기업명이 주어지면, 기업에 대한 설명을 작성해줘."

# %%
llm_han = utils.get_gpt_answer("한탑", prompt)
# Out:
# ## Query : 한탑/n/n## Answer : 한탑은 주로 국내외 건설 사업에 관련된 다양한 제품과 서비스를 제공하는 기업입니다. 이 회사는 건설 재료 제조 및 유통에 중점을 두고 있으며, 주요 제품으로는 시멘트, 콘크리트 및 기타 건설 자재가 포함됩니다. 한탑은 건설 산업의 여러 분야와 협력하여 프로젝트의 효율성을 높이고 품질을 강화하는 데 기여하고 있습니다. 또한, 지속 가능한 건설 자재의 개발과 환경 친화적 정책을 추진하여 시장에서의 경쟁력을 유지하고자 합니다.

# %%
llm_samsung = utils.get_gpt_answer("삼성전자", prompt)
llm_lg = utils.get_gpt_answer("LG전자", prompt)
llm_sk = utils.get_gpt_answer("SK하이닉스", prompt)
# Out:
# ## Query : 삼성전자/n/n## Answer : 삼성전자는 한국을 대표하는 글로벌 전자회사로, 소비자 가전, 모바일 기기, 반도체, 디스플레이 패널 등 다양한 전자 제품과 기술 솔루션을 제공하고 있습니다. 이 회사는 특히 메모리 반도체와 OLED 디스플레이 분야에서 세계 시장을 선도하고 있으며, 스마트폰 브랜드인 갤럭시 시리즈로도 널리 알려져 있습니다. 삼성전자는 혁신적인 기술 개발과 대규모 생산능력을 통해 글로벌 시장에서 막강한 경쟁력을 유지하고 있으며, 인공지능, 5G, 사물인터넷(IoT)와 같은 신기술 분야에도 적극적으로 투자하고 있습니다. 본사는 대한민국 경기도 수원시에 위치해 있으며, 글로벌 주요 시장에서 연구개발(R&D) 센터와 제조 시설을 운영하고 있습니다.
# ## Query : LG전자/n/n## Answer : LG전자는 대한민국을 대표하는 글로벌 전자기업 중 하나로, LG그룹에 소속되어 있습니다. 1958년에 금성사로 설립되어 1995년에 현재의 이름인 LG전자로 변경되었습니다. 회사의 본사는 서울특별시에 위치해 있으며, 전 세계에 다양한 생산 및 연구 시설을 운영하고 있습니다.
#
# LG전자는 광범위한 전자제품과 솔루션을 제공하는 기업으로, 주요 사업 분야에는 가전제품, 모바일 통신기기, 홈 엔터테인먼트, 에어 솔루션, 에너지 솔루션 등이 포함됩니다. 대표적인 제품으로는 냉장고, 세탁기, 에어컨, 텔레비전, 스마트폰, 모니터 등이 있습니다. 특히, TV와 가전제품 분야에서 혁신적인 기술력과 디자인으로 글로벌 시장에서 높은 평가를 받고 있습니다.
#
# 또한 LG전자는 인공지능(AI), 사물인터넷(IoT), 로봇 등 첨단 기술을 접목하여 스마트 홈과 스마트 시티 솔루션을 강화하고 있습니다. 지속 가능한 에너지 관리와 친환경 제품 개발에도 주력하면서, 글로벌 시장에서 친환경 전자제품 분야의 선두주자로 자리매김하고 있습니다.
#
# ...

# %%
llm_lg_che = utils.get_gpt_answer("LG화학", prompt)
# Out:
# ## Query : LG화학/n/n## Answer : LG화학은 대한민국을 대표하는 화학 기업으로, LG그룹의 계열사 중 하나입니다. 1947년에 설립된 이래로, LG화학은 석유화학, 첨단소재, 생명과학 등 다양한 부문에서 사업을 펼치고 있습니다.
#
# 1. **석유화학 부문**: LG화학은 에틸렌, 프로필렌 등 기초 원료를 비롯해 PE(폴리에틸렌), PVC(폴리염화비닐), ABS(아크릴로니트릴 부타디엔 스티렌) 등 다양한 플라스틱 및 합성수지를 생산합니다. 이러한 제품은 포장재, 전자기기, 자동차 부품 등 다양한 분야에서 활용되고 있습니다.
#
# 2. **첨단소재 부문**: 이 부문에서는 전기차 배터리 소재, OLED 소재, 반도체 소재 등을 개발 및 생산하고 있습니다. 특히 전기차 배터리 분야에서는 세계적으로 주목받는 기업 중 하나로, 주요 자동차 제조사들과 협력 관계를 맺고 있습니다.
#
# 3. **생명과학 부문**: LG화학은 의약품, 백신, 진단 제품을 포함한 다양한 바이오 사업을 운영하고 있습니다. 특히, 당뇨병 및 항암제 분야에서 연구개발을 활발히 진행하고 있습니다.
#
# LG화학은 지속 가능한 경영을 목표로 하여 친환경 제품 개발 및 탄소 중립을 위한 노력을 계속하고 있으며, 글로벌 시장에서의 확장을 위해 꾸준히 투자하고 있습니다. 이러한 다양한 사업 분야와 혁신적인 제품 개발은 LG화학을 글로벌 선두 화학 기업 중 하나로 자리매김하는 데 기여하고 있습니다.

# %%
utils.calculate_cosine_similarity(llm_samsung, llm_lg)
# Out:
# 0.590210596610644

# %%
utils.calculate_cosine_similarity(llm_lg, llm_sk)
# Out:
# 0.41263054415041733

# %%
utils.calculate_cosine_similarity(llm_samsung, llm_sk)
# Out:
# 0.4927589843738204

# %%
utils.calculate_cosine_similarity(llm_samsung, llm_busta)
# Out:
# 0.3313114630747851

# %%
llm_lg
# Out:
# 'LG전자는 대한민국을 대표하는 글로벌 전자 기업 중 하나로, 1958년에 설립되어 소비자 가전, 모바일 커뮤니케이션, 가전제품, 자동차 부품 및 디지털 디스플레이 솔루션 등 다양한 분야에서 사업을 운영하고 있습니다. LG전자는 특히 가전제품과 TV 분야에서 세계적인 경쟁력을 가지고 있으며, 혁신적인 기술과 디자인으로 시장을 선도하고 있습니다.\n\n회사는 크게 홈 어플라이언스 & 에어 솔루션(Home Appliance & Air Solution), 홈 엔터테인먼트(Home Entertainment), 모바일 커뮤니케이션즈(Mobile Communications), 그리고 비히클 컴포넌트 솔루션스(Vehicle Component Solutions)의 네 가지 주요 사업 부문으로 나뉩니다. 이러한 각 사업 부문들은 각각의 전문 분야에서 높은 기술력과 품질을 자랑하며, 지속 가능한 성장을 위해 연구개발에 집중하고 있습니다.\n\nLG전자는 또한 환경 보호와 사회적 책임을 강조하며 지속 가능한 발전을 위한 다양한 정책을 채택하고 있습니다. 이를 통해 글로벌 시장에서의 입지를 강화하고, 고객들에게 보다 나은 삶의 가치를 제공하기 위해 끊임없이 노력하고 있는 기업입니다.'

# %%
llm_sk
# Out:
# 'SK하이닉스는 대한민국을 대표하는 반도체 제조 회사 중 하나로, 주로 메모리 반도체를 설계하고 제조하는 데 주력하고 있습니다. 1983년에 설립된 이 회사는 전 세계 최대 메모리칩 공급업체 중 하나로 자리 잡고 있으며, DRAM(디램)과 NAND 플래시 메모리 분야에서 특히 강점을 보이고 있습니다.\n\nSK하이닉스는 SK그룹의 한 계열사로, 지속적인 연구 개발과 혁신을 통해 반도체 기술의 선두 주자로서의 입지를 공고히 하고 있습니다. 회사는 세계적인 생산 능력과 기술력을 바탕으로 다양한 응용 분야에 메모리 제품을 공급하고 있으며, 모바일 장치, 서버, PC, 자동차 등 다양한 분야에서 그 활용도를 자랑합니다.\n\n회사는 글로벌 고객들과의 긴밀한 관계를 유지하며, 기술 협력을 통해 제품의 품질과 성능을 향상시키는 데 집중하고 있습니다. 또한, 친환경 경영과 사회적 책임을 강조하며 지속 가능한 성장을 목표로 하고 있습니다. SK하이닉스는 실리콘웍스와 같은 다른 계열사와의 협력을 통해 반도체 생태계를 강화하고 있으며, 미래 기술 개발에 대한 투자 또한 아끼지 않고 있습니다.'

# %%
llm_lg_che
# Out:
# 'LG화학은 대한민국의 대표적인 화학 기업으로, LG그룹 계열사 중 하나입니다. 1947년에 설립된 LG화학은 다양한 화학 제품과 솔루션을 제공하며, 특히 전지, 석유화학, 첨단소재 분야에서 주도적인 위치를 차지하고 있습니다.\n\n1. **전지 사업부**: LG화학의 전지 사업부는 전기차 배터리, 에너지 저장 시스템(ESS), IT & 통신기기 등의 리튬이온 배터리를 생산하고 있으며 세계 시장에서 주요한 배터리 공급업체 중 하나로 성장했습니다.\n\n2. **석유화학 사업부**: 이 부서는 PVC, ABS, 고분자, 합성고무 등의 다양한 석유화학 제품을 생산 및 판매합니다. LG화학의 석유화학 제품은 건축, 자동차, 전자기기 등 여러 산업에 폭넓게 사용되고 있습니다.\n\n3. **첨단소재 사업부**: 첨단소재 부문에서는 정보전자소재 및 산업소재를 다루며, 특히 OLED 소재, 반도체 재료, 고기능성 필름 등 고부가가치 제품의 개발에 집중하고 있습니다.\n\nLG화학은 지속 가능한 성장과 친환경 사업에 대한 투자에도 많은 노력을 기울이고 있습니다. 기업은 환경 보호와 사회적 책임을 중시하며, 재생가능 에너지와 친환경 소재로의 전환을 통해 새로운 시장 기회를 창출하고 있습니다.\n\n기업의 글로벌 네트워크는 아시아, 미주, 유럽 등 전 세계에 걸쳐 있으며, 이를 통해 국제적으로 다양한 고객 기반을 확보하고 있습니다. LG화학은 연구개발에 대한 지속적인 투자로 기술력을 강화하고 있으며, 이를 통해 전 세계 화학 산업에서의 리더십을 유지하고 있습니다.'
