# %%
# !pip install marker-pdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 2.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 6.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 6.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.1
#     Uninstalling scikit-learn-1.5.1:
#       Successfully uninstalled scikit-learn-1.5.1
# ...

# %%
# !marker /mnt/c/Users/Shic/legal_graph/DCM/1-2 /mnt/c/Users/Shic/legal_graph/DCM/1-2/test
# Out:
# config.json: 100%|█████████████████████████████| 811/811 [00:00<00:00, 8.24MB/s]
# model.safetensors: 100%|█████████████████████| 154M/154M [00:10<00:00, 14.1MB/s]
# Loaded detection model vikp/surya_det3 on device cpu with dtype torch.float32
# preprocessor_config.json: 100%|████████████████| 675/675 [00:00<00:00, 2.13MB/s]
# config.json: 100%|█████████████████████████| 1.32k/1.32k [00:00<00:00, 7.29MB/s]
# model.safetensors: 100%|█████████████████████| 154M/154M [00:09<00:00, 16.0MB/s]
# Loaded detection model vikp/surya_layout3 on device cpu with dtype torch.float32
# preprocessor_config.json: 100%|████████████████| 373/373 [00:00<00:00, 1.25MB/s]
# config.json: 100%|█████████████████████████| 5.04k/5.04k [00:00<00:00, 31.5MB/s]
# model.safetensors: 100%|█████████████████████| 550M/550M [00:35<00:00, 15.5MB/s]
# generation_config.json: 100%|███████████████████| 160/160 [00:00<00:00, 975kB/s]
# Loaded reading order model vikp/surya_order on device cpu with dtype torch.float32
# ...
